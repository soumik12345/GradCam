# %%
import tensorflow as tf
from utils import visualize
from matplotlib import pyplot as plt
from gradcam import generate_cam, generate_heatmap

# %%
original_image, cam = generate_cam('./dog_1.jpg', tf.keras.applications.vgg16.VGG16, 'block5_conv3', 235)
original_image.shape, cam.shape
# Out:
# ((416, 831, 3), TensorShape([14, 14]))

# %%
cam, cam_overlayed = generate_heatmap(original_image, cam)
cam.shape, cam_overlayed.shape
# Out:
# ((224, 224, 3), (224, 224, 3))

# %%
visualize(original_image, cam, cam_overlayed)
