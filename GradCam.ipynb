# %%
# !git clone https://github.com/soumik12345/GradCam
# Out:
# Cloning into 'GradCam'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 20 (delta 5), reused 18 (delta 3), pack-reused 0
# Unpacking objects: 100% (20/20), done.

# %%
import os
os.chdir('./GradCam')
import tensorflow as tf
from utils import visualize
from matplotlib import pyplot as plt
from gradcam import generate_cam, generate_heatmap

# %%
original_image, cam = generate_cam('./assets/dog_1.jpg', tf.keras.applications.vgg16.VGG16, 'block5_conv3', 235)
cam, cam_overlayed = generate_heatmap(original_image, cam)
visualize(original_image, cam, cam_overlayed)

# %%
original_image, cam = generate_cam('./assets/cat_1.jpg', tf.keras.applications.vgg16.VGG16, 'block5_conv3', 281)
cam, cam_overlayed = generate_heatmap(original_image, cam)
visualize(original_image, cam, cam_overlayed)
